# %% [markdown]
# # Utilizing tf_geometric to build GCN model on ETH dataset

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import pyreadr
from sklearn.model_selection import train_test_split 
import networkx as nx
from ast import literal_eval
import graphviz
import pydot
import tf_geometric as tfg
from dfply import *
from sklearn.preprocessing import LabelEncoder
import math
from sklearn.metrics import DistanceMetric
from imblearn.over_sampling import SMOTE, ADASYN
from collections import Counter
from sklearn.metrics import accuracy_score, f1_score, classification_report,confusion_matrix
from tensorflow.keras import regularizers
import requests
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
from urllib.request import Request, urlopen
import requests
from bs4 import BeautifulSoup
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/__init__.py:169: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(module.__version__) < minver:
# /opt/anaconda3/lib/python3.8/site-packages/setuptools/_distutils/version.py:346: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/__init__.py:169: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(module.__version__) < minver:
# /opt/anaconda3/lib/python3.8/site-packages/setuptools/_distutils/version.py:346: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/__init__.py:169: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(module.__version__) < minver:
# /opt/anaconda3/lib/python3.8/site-packages/setuptools/_distutils/version.py:346: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/__init__.py:169: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(module.__version__) < minver:
# /opt/anaconda3/lib/python3.8/site-packages/setuptools/_distutils/version.py:346: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/__init__.py:169: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(module.__version__) < minver:
# /opt/anaconda3/lib/python3.8/site-packages/setuptools/_distutils/version.py:346: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)

# %%
import warnings
warnings.filterwarnings("ignore")
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Loading all ERC1155 data
#all_erc1155_data = pyreadr.read_r('data/ERC1155_data_07.rds') # also works for RData
#df_erc1155 = all_erc1155_data[None] # extract the pandas data frame 
all_erc1155_data = pyreadr.read_r('data/ERC1155_data_07_v2.rds') # also works for RData
df_erc1155 = all_erc1155_data[None] # extract the pandas data frame 



# Loading ERC20 data for train, validation sets
all_erc20_data = pd.read_csv('Dataset/Dataset.csv')

# %%
# Ensuring features are the same for both datasets
df_erc1155 = df_erc1155[['fromAddress', 'toAddress', 'data', 'blockNumber',
                        'transactionHash', 'transactionIndex', 'dateTime', 'priceETH',
                        'gasPrice', 'gasUsed']]

df_erc1155.columns = ['from_address', 'to_address', 'data', 'block_number',
                        'transaction_hash', 'transaction_index', 'timeStamp', 'priceETH',
                     'gas_price', 'receipt_gas_used']
df_erc1155['weight'] = df_erc1155['priceETH']


erc20_data_y = all_erc20_data[['from_scam', 'to_scam', 'from_category', 'to_category']]
erc20_data_y = pd.get_dummies(erc20_data_y, columns=['from_category', 'to_category'], prefix=["from_scam", "to_scam"])


erc20_data_X = all_erc20_data[['hash', 'transaction_index', 'from_address', 'to_address', 
                          'value', 'input', 'block_timestamp', 'block_number', 
                               'gas_price', 'receipt_gas_used', 'from_scam', 'to_scam']]
erc20_data_X.columns = ['transaction_hash', 'transaction_index', 'from_address', 'to_address', 
                          'priceWei', 'data', 'timeStamp', 'block_number', 'gas_price', 
                        'receipt_gas_used', 'from_scam', 'to_scam']

erc20_data_X['priceETH'] = erc20_data_X['priceWei']/1000000000000000000.00
erc20_data_X.drop(columns=['priceWei'])
#erc20_data_X['weight'] = erc20_data_X['priceETH']
# Out:
#                                         transaction_hash  transaction_index  \
# 0      0x253ec84729f5c11437f5346830e6bdc9857171b16097...                  4
# 1      0xfa5f1d7715562adb1e408fdbbbbfc033ae4fadca1e07...                 85
# 2      0x37928f1d12ee769d0876695aaa815c13d705f8b1e376...                 31
# 3      0xaad886f331a2fb40495cdf5faa10882852fcd324f064...                 78
# 4      0x3dbe36fd1a1b01b5e1b343ff78ec1ec189feee5acf46...                 83
# ...                                                  ...                ...
# 71245  0x3ea1ea78fe7107fa15f667266c66dc63786b6470dbd1...                204
# 71246  0x29931318eac76fb7ec086cbfaee3d95994c554a466f4...                101
# 71247  0x71741c64fff59755c32e14e0fa53bc4a4ad51ff3545a...                201
# 71248  0x28fb91f62b1948d044db2db46411ea0042473d158353...                 36
# 71249  0xb74c8334a51097a94b1796ae16a85e009c355b58ceec...                 61
#
#                                      from_address  \
# 0      0x267be1c1d684f78cb4f6a176c4911b741e4ffdc0
# 1      0x304cc179719bc5b05418d6f7f6783abe45d83090
# 2      0x304cc179719bc5b05418d6f7f6783abe45d83090
# 3      0x304cc179719bc5b05418d6f7f6783abe45d83090
# 4      0x304cc179719bc5b05418d6f7f6783abe45d83090
# ...                                           ...
# 71245  0x7c9001c50ea57c1b2ec1e3e63cf04c297534bfc1
# 71246  0xf49874712828e3d73a12c15f9f77c5529eb0632f
# 71247  0x7c9001c50ea57c1b2ec1e3e63cf04c297534bfc1
# 71248  0xf49874712828e3d73a12c15f9f77c5529eb0632f
# 71249  0x7c9001c50ea57c1b2ec1e3e63cf04c297534bfc1
#
#                                        to_address data  \
# 0      0xd707ac0098599006f0857e8da4c950795645ba01   0x
# 1      0xb8f6e76d34d4877732dfefa6b6a4e2a834a9092b   0x
# 2      0x5ec492652d7b92421680f21169ff6a8dbbc622ab   0x
# 3      0xdf01b231b53d8b4cbb1b092a8dc86730cebf4aa9   0x
# 4      0xaa4b9693c54029d180134161cc99e98b76cea249   0x
# ...                                           ...  ...
# 71245  0x4fed1fc4144c223ae3c1553be203cdfcbd38c581   0x
# 71246  0x7c9001c50ea57c1b2ec1e3e63cf04c297534bfc1   0x
# 71247  0x4fed1fc4144c223ae3c1553be203cdfcbd38c581   0x
# 71248  0x7c9001c50ea57c1b2ec1e3e63cf04c297534bfc1   0x
# 71249  0x4fed1fc4144c223ae3c1553be203cdfcbd38c581   0x
#
#                        timeStamp  block_number     gas_price  \
# 0        2017-10-16 05:26:53 UTC       4370008  2.205000e+10
# 1        2017-10-16 05:28:49 UTC       4370014  2.060947e+10
# 2        2017-10-16 05:29:19 UTC       4370015  2.060947e+10
# 3        2017-10-16 05:29:43 UTC       4370016  2.060947e+10
# 4        2017-10-16 05:29:43 UTC       4370016  2.060947e+10
# ...                          ...           ...           ...
# 71245  2019-12-26 10:28:03+00:00       9165303  3.000000e+09
# 71246  2019-12-30 05:40:39+00:00       9184428  5.000000e+09
# 71247  2019-12-30 05:46:10+00:00       9184447  1.500000e+09
# 71248  2019-12-30 12:58:56+00:00       9185936  6.000000e+09
# 71249  2019-12-30 13:03:40+00:00       9185954  5.000000e+09
#
#        receipt_gas_used  from_scam  to_scam  priceETH
# 0                 21000          0        0    1.8000
# 1                 21000          0        0    0.0075
# 2                 21000          0        0    0.0075
# 3                 21000          0        0    0.0075
# 4                 21000          0        0    0.0075
# ...                 ...        ...      ...       ...
# 71245             21000          1        0    0.6530
# 71246             21000          0        1    1.0900
# 71247             21000          1        0    1.0900
# 71248             21000          0        1    0.0480
# 71249             21000          1        0    0.0479
#
# [71250 rows x 12 columns]

# %%
# Convert hexadecimal to decimal
df_erc1155['gas'] = [literal_eval(y) if y != '0x' and type(y) != int else y for y in df_erc1155['receipt_gas_used']]

# %% [markdown]
# ###### ERC20 Dataset

# %%
# Creating scam/not-scam labelled addresses for ERC20 dataset

from_addresses = all_erc20_data >> select(X.from_address, X.from_scam)
to_addresses = all_erc20_data >> select(X.to_address, X.to_scam)

labelled_addresses = pd.merge(from_addresses, to_addresses, how = 'outer',
                             left_on = 'from_address', right_on = 'to_address')


labelled_addresses['address'] = labelled_addresses['from_address'].fillna(labelled_addresses['to_address'])
labelled_addresses['label'] = labelled_addresses['from_scam'].fillna(labelled_addresses['to_scam']).astype('int32')

labelled_addresses = labelled_addresses.drop_duplicates()
labelled_addresses = (labelled_addresses >> select(X.address, X.label)).reset_index(drop = True)

labelled_addresses.shape
# Out:
# (73034, 2)

# %%
# This block of code is unused as there are more issues when trying deal with 
# multiple categories with very few instances

# Creating specific kind of scam labelled addresses for ERC20 dataset
#le = LabelEncoder()

#from_addresses = all_erc20_data >> select(X.from_address, X.from_category)
#to_addresses = all_erc20_data >> select(X.to_address, X.to_category)

#from_addresses['from_category'] = (le.fit_transform(from_addresses['from_category']))
#from_addresses['from_category'] = from_addresses['from_category'].astype('category')


#mapping_dict = dict(zip(le.classes_, le.transform(le.classes_)))
#to_addresses['to_category'] = to_addresses['to_category'].map(mapping_dict)

#labelled_addresses_cats = pd.merge(from_addresses, to_addresses, how = 'outer',
#                             left_on = 'from_address', right_on = 'to_address')

#labelled_addresses_cats['address'] = labelled_addresses_cats['from_address'].fillna(labelled_addresses_cats['to_address'])
#labelled_addresses_cats['label'] = labelled_addresses_cats['from_category'].fillna(labelled_addresses_cats['to_category']).astype('int32')

#labelled_addresses_cats = labelled_addresses_cats.drop_duplicates()
#labelled_addresses_cats = (labelled_addresses_cats >> select(X.address, X.label)).reset_index(drop = True)


#labelled_addresses_cats.shape

# %%
G =  nx.from_pandas_edgelist(df = erc20_data_X, source='from_address', 
                                        target='to_address',
                                        edge_attr = ['transaction_hash', 'transaction_index', 
                                         'priceETH', 'timeStamp', 'block_number', 'gas_price',
                                         'receipt_gas_used'],
                                       create_using = nx.DiGraph())
df_nodes = pd.DataFrame({'node_id': G.nodes})

df_eig_centrality = pd.DataFrame.from_dict(nx.eigenvector_centrality_numpy(G), orient='index').reset_index()
df_eig_centrality.rename(columns={'index':'node_id', 0:'eigenvector_centrality'}, inplace=True)

df_pangerank = pd.DataFrame.from_dict(nx.pagerank(G), orient='index').reset_index()
df_pangerank.rename(columns={'index':'node_id', 0:'pagerank'}, inplace=True)

df_in_degree = pd.DataFrame.from_dict(dict(G.in_degree(G.nodes)), orient='index').reset_index()
df_in_degree.rename(columns={'index':'node_id', 0:'in_degree'}, inplace=True)

df_out_degree = pd.DataFrame.from_dict(dict(G.out_degree(G.nodes)), orient='index').reset_index()
df_out_degree.rename(columns={'index':'node_id', 0:'out_degree'}, inplace=True)

df_nodes = df_nodes.merge(df_eig_centrality, on='node_id')
df_nodes = df_nodes.merge(df_pangerank, on='node_id')
df_nodes = df_nodes.merge(df_in_degree, on='node_id')
df_nodes = df_nodes.merge(df_out_degree, on='node_id')

# %%
#Convert block_timestamp to timestamps
all_erc20_data['block_timestamp'] = pd.to_datetime(all_erc20_data['block_timestamp']).astype(int)

# For every from_address, collect the timestamps
adr_timestamp = (all_erc20_data >> select(X.from_address, X.block_timestamp) >>
mutate(timestamps = X.block_timestamp) >> #(X.block_timestamp).to_numpy(dtype = np.float32)) >>
select(~X.block_timestamp))

adr_timestamp = (adr_timestamp >> group_by(X.from_address) >>
summarize(min_timestamp = X.timestamps.min(),
      max_timestamp = (X.timestamps).max(),
      med_timestamp = (X.timestamps).median(),
      mean_timestamp = (X.timestamps).mean()))


# For every from_address, collect the reciept_gas/gas_used
adr_gas = (all_erc20_data >> select(X.from_address, X.receipt_gas_used) >>
mutate(gas = (X.receipt_gas_used).to_numpy(dtype = np.float32)) >>
select(~X.receipt_gas_used))
                
adr_gas = (adr_gas >> group_by(X.from_address) >>
summarize(min_gas = X.gas.min(),
      max_gas = (X.gas).max(),
      med_gas = (X.gas).median(),
      mean_gas = (X.gas).mean()))


# For every from_address, count the number of transactions made
outgoing_count = (all_erc20_data >> select(X.from_address) >> 
group_by(X.from_address) >> summarize(out_count = (X.from_address).count()))


# For every from_address, count the number of incoming transactions
incoming_count = (all_erc20_data >> select(X.to_address) >> 
group_by(X.to_address) >> summarize(in_count = (X.to_address).count()))

# For every from_address, calculate the value of outgoing transactions
outgoing_val = (erc20_data_X >> select(X.from_address, X.priceETH) >>
#group_by(X.from_address) >> summarize(outgoing_priceETH = (X.priceETH).to_numpy(dtype = np.float32)) >>
#ungroup()) #>> select(~X.outgoing_priceETH))
mutate(outgoing_priceETH = (X.priceETH).to_numpy(dtype = np.float32)) >>
select(~X.priceETH))
                
outgoing_val = (outgoing_val >> group_by(X.from_address) >>
summarize(min_outgoing_priceETH = X.outgoing_priceETH.min(), #>>
      max_outgoing_priceETH = (X.outgoing_priceETH).max(),
      med_outgoing_priceETH = (X.outgoing_priceETH).median(),
      mean_outgoing_priceETH = (X.outgoing_priceETH).mean()))# >>

# For every to_address, calculate the value of incoming transactions
incoming_val = (erc20_data_X >> select(X.to_address, X.priceETH) >>
mutate(incoming_priceETH = (X.priceETH).to_numpy(dtype = np.float32)) >>
select(~X.priceETH))
                
incoming_val = (incoming_val >> group_by(X.to_address) >>
summarize(min_incoming_priceETH = X.incoming_priceETH.min(), #>>
      max_incoming_priceETH = (X.incoming_priceETH).max(),
      med_incoming_priceETH = (X.incoming_priceETH).median(),
      mean_incoming_priceETH = (X.incoming_priceETH).mean())) #>>

# %%
######## Creating Node Feature Matrix X ########

feature_matrix_1 = pd.merge(adr_timestamp, adr_gas, how = 'outer', on = 'from_address')
feature_matrix_2 = pd.merge(outgoing_count, outgoing_val, how = 'outer', on = 'from_address')
feature_matrix_3 = pd.merge(feature_matrix_1, feature_matrix_2, how = 'outer', on = 'from_address')

feature_matrix_4 = pd.merge(incoming_count, incoming_val, how = 'outer', on = 'to_address')

feature_matrix = pd.merge(feature_matrix_3, feature_matrix_4, how = 'outer', 
                          left_on = 'from_address', right_on = 'to_address')

feature_matrix['address'] = feature_matrix['from_address'].fillna(feature_matrix['to_address'])
feature_matrix = (feature_matrix >> select(~X.to_address, ~X.from_address))

feature_matrix = feature_matrix.drop_duplicates(subset = 'address')

feature_matrix = pd.merge(feature_matrix, df_nodes, how = 'outer', 
                          left_on = 'address', right_on = 'node_id')
feature_matrix = feature_matrix >> select(~X.node_id)

# %%
feature_matrix.head()
# Out:
#    min_timestamp  max_timestamp  med_timestamp  mean_timestamp  min_gas  \
# 0   1.518234e+18   1.518234e+18   1.518234e+18    1.518234e+18  21000.0
# 1   1.513671e+18   1.513671e+18   1.513671e+18    1.513671e+18  21000.0
# 2   1.519282e+18   1.519282e+18   1.519282e+18    1.519282e+18  21000.0
# 3   1.508164e+18   1.508164e+18   1.508164e+18    1.508164e+18  21000.0
# 4   1.518340e+18   1.518340e+18   1.518340e+18    1.518340e+18  21000.0
#
#    max_gas  med_gas  mean_gas  out_count  min_outgoing_priceETH  ...  \
# 0  21000.0  21000.0   21000.0        1.0                0.10000  ...
# 1  21000.0  21000.0   21000.0        1.0                0.00827  ...
# 2  21000.0  21000.0   21000.0        1.0                2.99000  ...
# 3  21000.0  21000.0   21000.0        1.0                0.10000  ...
# 4  21000.0  21000.0   21000.0        1.0                0.91200  ...
#
#    in_count  min_incoming_priceETH  max_incoming_priceETH  \
# 0       NaN                    NaN                    NaN
# 1       NaN                    NaN                    NaN
# 2       NaN                    NaN                    NaN
# 3       NaN                    NaN                    NaN
# 4       NaN                    NaN                    NaN
#
#    med_incoming_priceETH  mean_incoming_priceETH  \
# 0                    NaN                     NaN
# 1                    NaN                     NaN
# 2                    NaN                     NaN
# 3                    NaN                     NaN
# 4                    NaN                     NaN
#
#                                       address  eigenvector_centrality  \
# 0  0x00005b859f8fac331d73c5c70f74238876727498           -1.638406e-19
# 1  0x00019beb6f68d1268288b6a458a8fd90dd266455           -1.815283e-19
# 2  0x000352b4652dc4000c3e25f4ebc159a69f471531           -1.801535e-19
# 3  0x00038c2a3748fec0d18a3119d74577e450f6acbb           -1.045353e-20
# 4  0x000398c693a4c60109d003f92c512c2510f71608            1.482848e-19
#
#    pagerank in_degree  out_degree
# 0  0.000009         0           1
# 1  0.000009         0           1
# 2  0.000009         0           1
# 3  0.000009         0           1
# 4  0.000009         0           1
#
# [5 rows x 23 columns]

# %%
######## Creating Adjacency Matrix A (edge_index, edge_weight) ########

# Add labels to feature matrix to ensure order of labels and addresses

feature_matrix_lbls = pd.merge(feature_matrix, labelled_addresses, how = 'left',
                              on = 'address')


#############################

adr_ind_dict = dict(zip(feature_matrix['address'], np.arange(len(feature_matrix['address']))))

edge_Index_1 = [adr_ind_dict[adr] for adr in erc20_data_X['from_address']]
edge_Index_2 = [adr_ind_dict[adr] for adr in erc20_data_X['to_address']]

#############################

edge_Index = np.array([edge_Index_1, edge_Index_2])


edge_Weight = np.array(erc20_data_X['priceETH'], dtype=np.float32)

#A = (edge_Index, edge_Weight)

edge_Index.shape, edge_Weight.shape

#edge_index_dict = dict(zip(edge_Index_1, edge_Index_2))
#index_weight_dict = dict(zip(zip(edge_Index_1, edge_Index_2), edge_Weight))
# Out:
# ((2, 71250), (71250,))

# %% [markdown]
# # Building Graphs

# %%
# Creating the Y list (of labels)
y = feature_matrix_lbls >> select(X.label)
y = np.array(y).astype(np.int32)
y = np.reshape(y, (-1))

X_feats = feature_matrix_lbls >> select(~X.label)

# Drop the address column from X
X_feats = X_feats >> select(~X.address)

# %%
# Converting feature matrix to useable form for graph
X_feats.fillna(-1, inplace=True)

#X_feats = np.asarray(X_feats)#.astype(np.float32)
#X_feats = np.reshape(X_feats, (73034,18))

# %%
X_feats_new = np.asarray(X_feats)#.astype(np.float32)
X_feats_new = np.reshape(X_feats_new, (73034,-1))

y_new = y

# %% [markdown]
# # GCN Utilizing tf_geometric

# %%
## Soruce: https://tf-geometric.readthedocs.io/en/latest/modules/root.html#graph-data-structure-for-a-single-graph

# %%
X_feats_new = feature_matrix_lbls >> select(~X.label)
X_feats_new.fillna(-1, inplace=True)

# %%
indices = np.arange(len(X_feats_new))
(_, _, _, _, train_index, test_index) = train_test_split(X_feats_new,
                                                         y_new,
                                                         indices, test_size = 0.25,
                                                         stratify = y_new,
                                                        random_state = 0)
valid_index = test_index[0:int(len(test_index) * .625)]
test_index = test_index[int(len(test_index) * .375):len(test_index)]

X_feats = X_feats_new >> select(~X.address)

X_feats = np.asarray(X_feats)
X_feats = np.reshape(X_feats, (73034,-1))

# Normalize according to training data
# Z-Normalization
#mean = np.mean(X_feats[train_index], axis=0)
#std = np.std(X_feats[train_index], axis=0)
#X_feats[train_index] -= mean
#X_feats[valid_index] -= mean
#X_feats[test_index] -= mean
#X_feats[train_index] /= std
#X_feats[valid_index] /= std
#X_feats[test_index] /= std

#Min/Max Normalization
X_min = np.min(X_feats[train_index], axis=0)
X_max = np.max(X_feats[train_index], axis=0)
X_feats[train_index] -= X_min
X_feats[valid_index] -= X_min
X_feats[test_index] -= X_min
X_feats[train_index] /= (X_max - X_min)
X_feats[valid_index] /= (X_max - X_min)
X_feats[test_index] /= (X_max - X_min)

######### Oversampling ######### 
from imblearn.over_sampling import RandomOverSampler

#over = RandomOverSampler(sampling_strategy = 0.10) #10
#XX, yy = over.fit_resample(X_feats_new.iloc[train_index], y_new[train_index])
#train_index = train_index[over.sample_indices_]

over2 = RandomOverSampler(sampling_strategy = 0.05) # 0.05
XX2, yy2 = over2.fit_resample(X_feats_new.iloc[valid_index], y_new[valid_index])
valid_index = valid_index[over2.sample_indices_]

# %%
sorted(Counter(np.array(y_new[train_index])).items()),
# Out:
# ([(0, 54648), (1, 127)],)

# %%
ERC20_Graph = tfg.Graph(x = X_feats,
                        y = y_new,
                        edge_index = edge_Index,
                        edge_weight = edge_Weight).to_directed()

# %%
from tf_geometric.utils import tf_utils

graph = ERC20_Graph

# @tf_utils.function can speed up functions for TensorFlow 2.x
@tf_utils.function
def forward(graph, training=False):
    return model([graph.x, graph.edge_index, graph.edge_weight], 
                 training=training, cache=graph.cache)


@tf_utils.function
def compute_loss(logits, mask_index, vars):
    masked_logits = tf.gather(logits, mask_index)
    masked_labels = tf.gather(graph.y, mask_index)
    losses = tf.nn.softmax_cross_entropy_with_logits(
        logits = masked_logits,
        labels = tf.one_hot(masked_labels, depth=num_classes),)

    kernel_vals = [var for var in vars if "kernel" in var.name]
    l2_losses = [tf.nn.l2_loss(kernel_var) for kernel_var in kernel_vals]
    cls_loss = tf.reduce_mean(losses)
    l2_loss = tf.add_n(l2_losses)
    return cls_loss + l2_loss * l2_coef, cls_loss, l2_loss


@tf_utils.function
def evaluate(current_test_index):
    with tf.GradientTape() as tape:
        logits = forward(graph)
        loss = compute_loss(logits, current_test_index, tape.watched_variables())
    masked_logits = tf.gather(logits, current_test_index)
    masked_labels = tf.gather(graph.y, current_test_index)
    y_pred = tf.argmax(masked_logits, axis=-1, output_type=tf.int32)
    
    corrects = tf.equal(y_pred, masked_labels)
    accuracy = tf.reduce_mean(tf.cast(corrects, tf.float32))

    return accuracy, loss


@tf_utils.function
def evaluate_test():
    return evaluate(test_index)


@tf_utils.function
def evaluate_val():
    return evaluate(valid_index)

@tf_utils.function
def train_step():

    over = RandomOverSampler(sampling_strategy = 0.06)
    XX, yy = over.fit_resample(graph.x[train_index], graph.y[train_index])
    train_index2 = train_index[over.sample_indices_]

    with tf.GradientTape() as tape:
        logits = forward(graph, training=True)
        loss, _, _ = compute_loss(logits, train_index2, tape.watched_variables())
    vars = tape.watched_variables()
    grads = tape.gradient(loss, vars)
    optimizer.apply_gradients(zip(grads, vars))
    
    ###
    masked_logits = tf.gather(logits, train_index2)
    masked_labels = tf.gather(graph.y, train_index2)
    y_pred = tf.argmax(masked_logits, axis=-1, output_type=tf.int32)

    corrects = tf.equal(y_pred, masked_labels)    
    accuracy = tf.reduce_mean(tf.cast(corrects, tf.float32))
    ###
    return accuracy, loss

@tf_utils.function
def predict(test_index):
    logits = forward(graph)
    masked_logits = tf.gather(logits, test_index)
    y_pred = tf.argmax(masked_logits, axis=-1, output_type=tf.int32)

    return y_pred

# %%
### GCN ###
# Source: https://github.com/CrawlScript/tf_geometric/blob/master/benchmarks/node_classification/bench_node_cls_early_stop_gcn.py

#tf.config.run_functions_eagerly(True)

patience = 4

num_classes = ERC20_Graph.y.max() + 1
drop_rate = 0.25 #0.25
l2_coef = 5e-3

# Multi-layer GCN Model
class GCNModel(keras.Model):

    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.gcn0 = tfg.layers.GCN(12, activation=tf.nn.relu, improved = True,
                                    edge_drop_rate = drop_rate,
                                  renorm = True) # 12
                
        self.gcn4 = tfg.layers.GCN(8, activation = tf.nn.relu, improved = True,
                                  edge_drop_rate = (drop_rate - 0.1)) # 8

        self.dense = tf.keras.layers.Dense(2,)

        
    def call(self, inputs, training=None, mask=None, cache=None):
        x, edge_index, edge_weight = inputs
        h = self.gcn0([x, edge_index, edge_weight], training = training, cache=cache)
        h = self.gcn4([h, edge_index, edge_weight], training = training, cache=cache)
        h = self.dense(h, training = training)
        return h


ETH_model = GCNModel()
model = ETH_model
model.gcn0.build_cache_for_graph(ERC20_Graph)

TC =  tf.keras.callbacks.TensorBoard(log_dir='./logs', 
                                     write_graph = True, write_images = True)
TC.set_model(model)

optimizer = tf.keras.optimizers.Adamax(learning_rate = 0.006,)#0.0075 )

model.compile(optimizer = optimizer,)

# %%
val_accuracy_list = []
loss_list = []

best_val_accuracy = 0
min_val_loss = 1000

final_step = None

patience_counter = 0

num_steps = 5121

for step in range(1, num_steps):

    #loss = train_step()
    accuracy, loss = train_step()

    if step % 28 == 0: #28
        val_accuracy, (_, val_loss, _) = evaluate_val()
        val_accuracy = val_accuracy#.numpy()
        val_loss = val_loss.numpy()
        
        # then after each epoch
        logs = {'acc': accuracy, 'loss': loss, 
                'val_loss': val_loss, 'val_acc': val_accuracy}
        TC.on_epoch_end(int(step), logs)

        if val_accuracy > best_val_accuracy or val_loss < min_val_loss:
            patience_counter = 0
        else:
            patience_counter += 1
            if patience_counter > patience:
                break

        if val_accuracy > best_val_accuracy and val_loss < min_val_loss:
            final_step = step

            best_val_accuracy = val_accuracy
            min_val_loss = val_loss

        val_accuracy_list.append(val_accuracy)
        loss_list.append(val_loss)

        print("step = {}\taccuracy = {:.4f}\tloss = {:.4f}\tval_accuracy = {:.4f}\tval_loss = {:.4f}\tfinal_step = {}"
            .format(step, accuracy, loss, val_accuracy, val_loss, final_step))       
        print("patience_counter = {}".format(patience_counter))

TC.on_train_end('_')


#model.summary()
# Out:
# step = 28	accuracy = 0.9434	loss = 0.3897	val_accuracy = 0.9524	val_loss = 0.3350	final_step = 28
# patience_counter = 0
# step = 56	accuracy = 0.9434	loss = 0.2885	val_accuracy = 0.9524	val_loss = 0.2329	final_step = 28
# patience_counter = 0
# step = 84	accuracy = 0.9434	loss = 0.2579	val_accuracy = 0.9524	val_loss = 0.1988	final_step = 28
# patience_counter = 0
# step = 112	accuracy = 0.9434	loss = 0.2358	val_accuracy = 0.9524	val_loss = 0.1816	final_step = 28
# patience_counter = 0
# step = 140	accuracy = 0.9434	loss = 0.2264	val_accuracy = 0.9524	val_loss = 0.1688	final_step = 28
# patience_counter = 0
# step = 168	accuracy = 0.9444	loss = 0.2125	val_accuracy = 0.9524	val_loss = 0.1579	final_step = 28
# patience_counter = 0
# step = 196	accuracy = 0.9465	loss = 0.2053	val_accuracy = 0.9545	val_loss = 0.1458	final_step = 196
# patience_counter = 0
# step = 224	accuracy = 0.9485	loss = 0.2019	val_accuracy = 0.9611	val_loss = 0.1372	final_step = 224
# patience_counter = 0
# step = 252	accuracy = 0.9489	loss = 0.1937	val_accuracy = 0.9634	val_loss = 0.1331	final_step = 252
# patience_counter = 0
# step = 280	accuracy = 0.9498	loss = 0.1972	val_accuracy = 0.9660	val_loss = 0.1310	final_step = 280
# patience_counter = 0
# step = 308	accuracy = 0.9513	loss = 0.1972	val_accuracy = 0.9685	val_loss = 0.1291	final_step = 308
# patience_counter = 0
# step = 336	accuracy = 0.9515	loss = 0.1910	val_accuracy = 0.9686	val_loss = 0.1293	final_step = 308
# patience_counter = 0
# step = 364	accuracy = 0.9520	loss = 0.1930	val_accuracy = 0.9686	val_loss = 0.1273	final_step = 364
# patience_counter = 0
# step = 392	accuracy = 0.9525	loss = 0.1912	val_accuracy = 0.9686	val_loss = 0.1265	final_step = 392
# patience_counter = 0
# step = 420	accuracy = 0.9536	loss = 0.1865	val_accuracy = 0.9687	val_loss = 0.1261	final_step = 420
# patience_counter = 0
# step = 448	accuracy = 0.9534	loss = 0.1897	val_accuracy = 0.9685	val_loss = 0.1247	final_step = 420
# patience_counter = 0
# step = 476	accuracy = 0.9538	loss = 0.1893	val_accuracy = 0.9687	val_loss = 0.1256	final_step = 420
# patience_counter = 0
# step = 504	accuracy = 0.9519	loss = 0.1850	val_accuracy = 0.9687	val_loss = 0.1247	final_step = 420
# patience_counter = 0
# step = 532	accuracy = 0.9531	loss = 0.1836	val_accuracy = 0.9686	val_loss = 0.1240	final_step = 420
# patience_counter = 0
# step = 560	accuracy = 0.9554	loss = 0.1824	val_accuracy = 0.9686	val_loss = 0.1237	final_step = 420
# patience_counter = 0
# step = 588	accuracy = 0.9532	loss = 0.1843	val_accuracy = 0.9686	val_loss = 0.1239	final_step = 420
# patience_counter = 0
# step = 616	accuracy = 0.9524	loss = 0.1875	val_accuracy = 0.9684	val_loss = 0.1241	final_step = 420
# patience_counter = 0
# step = 644	accuracy = 0.9543	loss = 0.1784	val_accuracy = 0.9685	val_loss = 0.1231	final_step = 420
# patience_counter = 0
# step = 672	accuracy = 0.9543	loss = 0.1815	val_accuracy = 0.9686	val_loss = 0.1231	final_step = 420
# patience_counter = 0
# step = 700	accuracy = 0.9545	loss = 0.1849	val_accuracy = 0.9685	val_loss = 0.1233	final_step = 420
# patience_counter = 0
# step = 728	accuracy = 0.9546	loss = 0.1805	val_accuracy = 0.9685	val_loss = 0.1229	final_step = 420
# patience_counter = 0
# step = 756	accuracy = 0.9547	loss = 0.1805	val_accuracy = 0.9685	val_loss = 0.1231	final_step = 420
# patience_counter = 0
# step = 784	accuracy = 0.9540	loss = 0.1833	val_accuracy = 0.9683	val_loss = 0.1230	final_step = 420
# patience_counter = 0
# step = 812	accuracy = 0.9546	loss = 0.1802	val_accuracy = 0.9684	val_loss = 0.1226	final_step = 420
# patience_counter = 0
# step = 840	accuracy = 0.9541	loss = 0.1793	val_accuracy = 0.9684	val_loss = 0.1222	final_step = 420
# patience_counter = 0
# step = 868	accuracy = 0.9533	loss = 0.1785	val_accuracy = 0.9684	val_loss = 0.1222	final_step = 420
# patience_counter = 0
# step = 896	accuracy = 0.9533	loss = 0.1774	val_accuracy = 0.9684	val_loss = 0.1226	final_step = 420
# patience_counter = 0
# step = 924	accuracy = 0.9534	loss = 0.1780	val_accuracy = 0.9684	val_loss = 0.1224	final_step = 420
# patience_counter = 0
# step = 952	accuracy = 0.9565	loss = 0.1773	val_accuracy = 0.9684	val_loss = 0.1225	final_step = 420
# patience_counter = 0
# step = 980	accuracy = 0.9541	loss = 0.1800	val_accuracy = 0.9684	val_loss = 0.1222	final_step = 420
# patience_counter = 0
# step = 1008	accuracy = 0.9536	loss = 0.1791	val_accuracy = 0.9682	val_loss = 0.1213	final_step = 420
# patience_counter = 0
# step = 1036	accuracy = 0.9537	loss = 0.1778	val_accuracy = 0.9684	val_loss = 0.1215	final_step = 420
# patience_counter = 0
# step = 1064	accuracy = 0.9553	loss = 0.1754	val_accuracy = 0.9682	val_loss = 0.1219	final_step = 420
# patience_counter = 0
# step = 1092	accuracy = 0.9551	loss = 0.1759	val_accuracy = 0.9684	val_loss = 0.1210	final_step = 420
# patience_counter = 0
# step = 1120	accuracy = 0.9535	loss = 0.1777	val_accuracy = 0.9683	val_loss = 0.1220	final_step = 420
# patience_counter = 0
# step = 1148	accuracy = 0.9539	loss = 0.1772	val_accuracy = 0.9683	val_loss = 0.1221	final_step = 420
# patience_counter = 0
# step = 1176	accuracy = 0.9536	loss = 0.1821	val_accuracy = 0.9682	val_loss = 0.1216	final_step = 420
# patience_counter = 0
# step = 1204	accuracy = 0.9578	loss = 0.1754	val_accuracy = 0.9684	val_loss = 0.1218	final_step = 420
# patience_counter = 0
# step = 1232	accuracy = 0.9555	loss = 0.1758	val_accuracy = 0.9683	val_loss = 0.1219	final_step = 420
# patience_counter = 0
# step = 1260	accuracy = 0.9542	loss = 0.1784	val_accuracy = 0.9682	val_loss = 0.1219	final_step = 420
# patience_counter = 0
# step = 1288	accuracy = 0.9543	loss = 0.1739	val_accuracy = 0.9682	val_loss = 0.1218	final_step = 420
# patience_counter = 0
# step = 1316	accuracy = 0.9544	loss = 0.1732	val_accuracy = 0.9684	val_loss = 0.1212	final_step = 420
# patience_counter = 0
# step = 1344	accuracy = 0.9553	loss = 0.1758	val_accuracy = 0.9683	val_loss = 0.1201	final_step = 420
# patience_counter = 0
# step = 1372	accuracy = 0.9547	loss = 0.1723	val_accuracy = 0.9683	val_loss = 0.1202	final_step = 420
# patience_counter = 0
# step = 1400	accuracy = 0.9539	loss = 0.1745	val_accuracy = 0.9683	val_loss = 0.1210	final_step = 420
# patience_counter = 0
# step = 1428	accuracy = 0.9546	loss = 0.1812	val_accuracy = 0.9683	val_loss = 0.1207	final_step = 420
# patience_counter = 0
# step = 1456	accuracy = 0.9559	loss = 0.1730	val_accuracy = 0.9683	val_loss = 0.1210	final_step = 420
# patience_counter = 0
# step = 1484	accuracy = 0.9551	loss = 0.1729	val_accuracy = 0.9683	val_loss = 0.1206	final_step = 420
# patience_counter = 0
# step = 1512	accuracy = 0.9544	loss = 0.1783	val_accuracy = 0.9684	val_loss = 0.1206	final_step = 420
# patience_counter = 0
# step = 1540	accuracy = 0.9547	loss = 0.1706	val_accuracy = 0.9682	val_loss = 0.1210	final_step = 420
# patience_counter = 0
# step = 1568	accuracy = 0.9561	loss = 0.1720	val_accuracy = 0.9682	val_loss = 0.1204	final_step = 420
# patience_counter = 0
# step = 1596	accuracy = 0.9544	loss = 0.1797	val_accuracy = 0.9683	val_loss = 0.1206	final_step = 420
# patience_counter = 0
# step = 1624	accuracy = 0.9553	loss = 0.1712	val_accuracy = 0.9683	val_loss = 0.1208	final_step = 420
# patience_counter = 0
# step = 1652	accuracy = 0.9558	loss = 0.1719	val_accuracy = 0.9682	val_loss = 0.1206	final_step = 420
# patience_counter = 0
# step = 1680	accuracy = 0.9530	loss = 0.1754	val_accuracy = 0.9683	val_loss = 0.1210	final_step = 420
# patience_counter = 0
# step = 1708	accuracy = 0.9556	loss = 0.1767	val_accuracy = 0.9682	val_loss = 0.1201	final_step = 420
# patience_counter = 0
# step = 1736	accuracy = 0.9545	loss = 0.1709	val_accuracy = 0.9682	val_loss = 0.1206	final_step = 420
# patience_counter = 0
# step = 1764	accuracy = 0.9549	loss = 0.1753	val_accuracy = 0.9682	val_loss = 0.1197	final_step = 420
# patience_counter = 0
# step = 1792	accuracy = 0.9535	loss = 0.1738	val_accuracy = 0.9682	val_loss = 0.1203	final_step = 420
# patience_counter = 0
# step = 1820	accuracy = 0.9546	loss = 0.1762	val_accuracy = 0.9682	val_loss = 0.1196	final_step = 420
# patience_counter = 0
# step = 1848	accuracy = 0.9552	loss = 0.1700	val_accuracy = 0.9682	val_loss = 0.1201	final_step = 420
# patience_counter = 0
# step = 1876	accuracy = 0.9562	loss = 0.1754	val_accuracy = 0.9683	val_loss = 0.1197	final_step = 420
# patience_counter = 0
# step = 1904	accuracy = 0.9548	loss = 0.1762	val_accuracy = 0.9680	val_loss = 0.1199	final_step = 420
# patience_counter = 0
# step = 1932	accuracy = 0.9541	loss = 0.1710	val_accuracy = 0.9680	val_loss = 0.1188	final_step = 420
# patience_counter = 0
# step = 1960	accuracy = 0.9555	loss = 0.1734	val_accuracy = 0.9682	val_loss = 0.1206	final_step = 420
# patience_counter = 0
# step = 1988	accuracy = 0.9554	loss = 0.1711	val_accuracy = 0.9680	val_loss = 0.1198	final_step = 420
# patience_counter = 0
# step = 2016	accuracy = 0.9566	loss = 0.1713	val_accuracy = 0.9683	val_loss = 0.1215	final_step = 420
# patience_counter = 0
# step = 2044	accuracy = 0.9539	loss = 0.1705	val_accuracy = 0.9682	val_loss = 0.1211	final_step = 420
# patience_counter = 0
# step = 2072	accuracy = 0.9554	loss = 0.1735	val_accuracy = 0.9683	val_loss = 0.1218	final_step = 420
# patience_counter = 0
# step = 2100	accuracy = 0.9577	loss = 0.1678	val_accuracy = 0.9682	val_loss = 0.1201	final_step = 420
# patience_counter = 0
# step = 2128	accuracy = 0.9558	loss = 0.1742	val_accuracy = 0.9681	val_loss = 0.1215	final_step = 420
# patience_counter = 0
# step = 2156	accuracy = 0.9555	loss = 0.1692	val_accuracy = 0.9682	val_loss = 0.1210	final_step = 420
# patience_counter = 0
# step = 2184	accuracy = 0.9549	loss = 0.1769	val_accuracy = 0.9682	val_loss = 0.1204	final_step = 420
# patience_counter = 0
# step = 2212	accuracy = 0.9564	loss = 0.1723	val_accuracy = 0.9681	val_loss = 0.1196	final_step = 420
# patience_counter = 0
# step = 2240	accuracy = 0.9563	loss = 0.1722	val_accuracy = 0.9680	val_loss = 0.1203	final_step = 420
# patience_counter = 0
# step = 2268	accuracy = 0.9569	loss = 0.1713	val_accuracy = 0.9681	val_loss = 0.1198	final_step = 420
# patience_counter = 0
# step = 2296	accuracy = 0.9548	loss = 0.1755	val_accuracy = 0.9682	val_loss = 0.1209	final_step = 420
# patience_counter = 0
# step = 2324	accuracy = 0.9559	loss = 0.1724	val_accuracy = 0.9681	val_loss = 0.1202	final_step = 420
# patience_counter = 0
# step = 2352	accuracy = 0.9540	loss = 0.1724	val_accuracy = 0.9682	val_loss = 0.1200	final_step = 420
# patience_counter = 0
# step = 2380	accuracy = 0.9569	loss = 0.1681	val_accuracy = 0.9682	val_loss = 0.1210	final_step = 420
# patience_counter = 0
# step = 2408	accuracy = 0.9550	loss = 0.1671	val_accuracy = 0.9681	val_loss = 0.1197	final_step = 420
# patience_counter = 0
# step = 2436	accuracy = 0.9562	loss = 0.1710	val_accuracy = 0.9681	val_loss = 0.1194	final_step = 420
# patience_counter = 0
# step = 2464	accuracy = 0.9538	loss = 0.1769	val_accuracy = 0.9681	val_loss = 0.1204	final_step = 420
# patience_counter = 0
# step = 2492	accuracy = 0.9569	loss = 0.1687	val_accuracy = 0.9681	val_loss = 0.1196	final_step = 420
# patience_counter = 0
# step = 2520	accuracy = 0.9540	loss = 0.1690	val_accuracy = 0.9681	val_loss = 0.1206	final_step = 420
# patience_counter = 0
# step = 2548	accuracy = 0.9541	loss = 0.1737	val_accuracy = 0.9681	val_loss = 0.1201	final_step = 420
# patience_counter = 0
# step = 2576	accuracy = 0.9554	loss = 0.1734	val_accuracy = 0.9681	val_loss = 0.1201	final_step = 420
# patience_counter = 0
# step = 2604	accuracy = 0.9546	loss = 0.1747	val_accuracy = 0.9681	val_loss = 0.1199	final_step = 420
# patience_counter = 0
# step = 2632	accuracy = 0.9567	loss = 0.1676	val_accuracy = 0.9681	val_loss = 0.1202	final_step = 420
# patience_counter = 0
# step = 2660	accuracy = 0.9569	loss = 0.1678	val_accuracy = 0.9680	val_loss = 0.1200	final_step = 420
# patience_counter = 0
# step = 2688	accuracy = 0.9537	loss = 0.1759	val_accuracy = 0.9681	val_loss = 0.1201	final_step = 420
# patience_counter = 0
# step = 2716	accuracy = 0.9571	loss = 0.1712	val_accuracy = 0.9681	val_loss = 0.1200	final_step = 420
# patience_counter = 0
# step = 2744	accuracy = 0.9534	loss = 0.1755	val_accuracy = 0.9681	val_loss = 0.1198	final_step = 420
# patience_counter = 0
# step = 2772	accuracy = 0.9569	loss = 0.1701	val_accuracy = 0.9681	val_loss = 0.1191	final_step = 420
# patience_counter = 0
# step = 2800	accuracy = 0.9563	loss = 0.1704	val_accuracy = 0.9681	val_loss = 0.1188	final_step = 420
# patience_counter = 0
# step = 2828	accuracy = 0.9563	loss = 0.1727	val_accuracy = 0.9681	val_loss = 0.1188	final_step = 420
# patience_counter = 0
# step = 2856	accuracy = 0.9564	loss = 0.1699	val_accuracy = 0.9681	val_loss = 0.1189	final_step = 420
# patience_counter = 0
# step = 2884	accuracy = 0.9546	loss = 0.1715	val_accuracy = 0.9681	val_loss = 0.1199	final_step = 420
# patience_counter = 0
# step = 2912	accuracy = 0.9567	loss = 0.1715	val_accuracy = 0.9683	val_loss = 0.1192	final_step = 420
# patience_counter = 0
# step = 2940	accuracy = 0.9554	loss = 0.1726	val_accuracy = 0.9681	val_loss = 0.1195	final_step = 420
# patience_counter = 0
# step = 2968	accuracy = 0.9551	loss = 0.1737	val_accuracy = 0.9682	val_loss = 0.1192	final_step = 420
# patience_counter = 0
# step = 2996	accuracy = 0.9546	loss = 0.1718	val_accuracy = 0.9681	val_loss = 0.1191	final_step = 420
# patience_counter = 0
# step = 3024	accuracy = 0.9549	loss = 0.1738	val_accuracy = 0.9683	val_loss = 0.1200	final_step = 420
# patience_counter = 0
# step = 3052	accuracy = 0.9575	loss = 0.1654	val_accuracy = 0.9681	val_loss = 0.1189	final_step = 420
# patience_counter = 0
# step = 3080	accuracy = 0.9570	loss = 0.1674	val_accuracy = 0.9682	val_loss = 0.1191	final_step = 420
# patience_counter = 0
# step = 3108	accuracy = 0.9559	loss = 0.1723	val_accuracy = 0.9681	val_loss = 0.1190	final_step = 420
# patience_counter = 0
# step = 3136	accuracy = 0.9555	loss = 0.1712	val_accuracy = 0.9681	val_loss = 0.1186	final_step = 420
# patience_counter = 0
# step = 3164	accuracy = 0.9563	loss = 0.1670	val_accuracy = 0.9681	val_loss = 0.1186	final_step = 420
# patience_counter = 0
# step = 3192	accuracy = 0.9552	loss = 0.1718	val_accuracy = 0.9683	val_loss = 0.1184	final_step = 420
# patience_counter = 0
# step = 3220	accuracy = 0.9573	loss = 0.1714	val_accuracy = 0.9684	val_loss = 0.1187	final_step = 420
# patience_counter = 0
# step = 3248	accuracy = 0.9569	loss = 0.1662	val_accuracy = 0.9681	val_loss = 0.1190	final_step = 420
# patience_counter = 0
# step = 3276	accuracy = 0.9570	loss = 0.1642	val_accuracy = 0.9681	val_loss = 0.1185	final_step = 420
# patience_counter = 0
# step = 3304	accuracy = 0.9553	loss = 0.1732	val_accuracy = 0.9684	val_loss = 0.1193	final_step = 420
# patience_counter = 0
# step = 3332	accuracy = 0.9553	loss = 0.1679	val_accuracy = 0.9681	val_loss = 0.1189	final_step = 420
# patience_counter = 0
# step = 3360	accuracy = 0.9543	loss = 0.1744	val_accuracy = 0.9683	val_loss = 0.1183	final_step = 420
# patience_counter = 0
# step = 3388	accuracy = 0.9569	loss = 0.1646	val_accuracy = 0.9681	val_loss = 0.1187	final_step = 420
# patience_counter = 0
# step = 3416	accuracy = 0.9572	loss = 0.1662	val_accuracy = 0.9683	val_loss = 0.1188	final_step = 420
# patience_counter = 0
# step = 3444	accuracy = 0.9563	loss = 0.1687	val_accuracy = 0.9681	val_loss = 0.1187	final_step = 420
# patience_counter = 0
# step = 3472	accuracy = 0.9575	loss = 0.1717	val_accuracy = 0.9681	val_loss = 0.1186	final_step = 420
# patience_counter = 0
# step = 3500	accuracy = 0.9578	loss = 0.1686	val_accuracy = 0.9681	val_loss = 0.1181	final_step = 420
# patience_counter = 0
# step = 3528	accuracy = 0.9577	loss = 0.1703	val_accuracy = 0.9684	val_loss = 0.1182	final_step = 420
# patience_counter = 0
# step = 3556	accuracy = 0.9545	loss = 0.1719	val_accuracy = 0.9684	val_loss = 0.1185	final_step = 420
# patience_counter = 0
# step = 3584	accuracy = 0.9553	loss = 0.1726	val_accuracy = 0.9684	val_loss = 0.1185	final_step = 420
# patience_counter = 0
# step = 3612	accuracy = 0.9581	loss = 0.1693	val_accuracy = 0.9684	val_loss = 0.1182	final_step = 420
# patience_counter = 0
# step = 3640	accuracy = 0.9566	loss = 0.1738	val_accuracy = 0.9681	val_loss = 0.1183	final_step = 420
# patience_counter = 0
# step = 3668	accuracy = 0.9575	loss = 0.1697	val_accuracy = 0.9682	val_loss = 0.1185	final_step = 420
# patience_counter = 0
# step = 3696	accuracy = 0.9580	loss = 0.1677	val_accuracy = 0.9683	val_loss = 0.1177	final_step = 420
# patience_counter = 0
# step = 3724	accuracy = 0.9539	loss = 0.1667	val_accuracy = 0.9684	val_loss = 0.1184	final_step = 420
# patience_counter = 0
# step = 3752	accuracy = 0.9569	loss = 0.1687	val_accuracy = 0.9682	val_loss = 0.1175	final_step = 420
# patience_counter = 0
# step = 3780	accuracy = 0.9565	loss = 0.1704	val_accuracy = 0.9681	val_loss = 0.1175	final_step = 420
# patience_counter = 0
# step = 3808	accuracy = 0.9565	loss = 0.1745	val_accuracy = 0.9684	val_loss = 0.1178	final_step = 420
# patience_counter = 0
# step = 3836	accuracy = 0.9573	loss = 0.1685	val_accuracy = 0.9684	val_loss = 0.1180	final_step = 420
# patience_counter = 0
# step = 3864	accuracy = 0.9566	loss = 0.1702	val_accuracy = 0.9684	val_loss = 0.1188	final_step = 420
# patience_counter = 0
# step = 3892	accuracy = 0.9539	loss = 0.1718	val_accuracy = 0.9684	val_loss = 0.1182	final_step = 420
# patience_counter = 0
# step = 3920	accuracy = 0.9576	loss = 0.1729	val_accuracy = 0.9684	val_loss = 0.1176	final_step = 420
# patience_counter = 0
# step = 3948	accuracy = 0.9563	loss = 0.1657	val_accuracy = 0.9682	val_loss = 0.1176	final_step = 420
# patience_counter = 0
# step = 3976	accuracy = 0.9573	loss = 0.1671	val_accuracy = 0.9684	val_loss = 0.1171	final_step = 420
# patience_counter = 0
# step = 4004	accuracy = 0.9538	loss = 0.1715	val_accuracy = 0.9684	val_loss = 0.1176	final_step = 420
# patience_counter = 0
# step = 4032	accuracy = 0.9552	loss = 0.1723	val_accuracy = 0.9684	val_loss = 0.1175	final_step = 420
# patience_counter = 0
# step = 4060	accuracy = 0.9568	loss = 0.1713	val_accuracy = 0.9700	val_loss = 0.1170	final_step = 4060
# patience_counter = 0
# step = 4088	accuracy = 0.9570	loss = 0.1685	val_accuracy = 0.9684	val_loss = 0.1178	final_step = 4060
# patience_counter = 1
# step = 4116	accuracy = 0.9562	loss = 0.1746	val_accuracy = 0.9684	val_loss = 0.1176	final_step = 4060
# patience_counter = 2
# step = 4144	accuracy = 0.9573	loss = 0.1624	val_accuracy = 0.9684	val_loss = 0.1180	final_step = 4060
# patience_counter = 3
# step = 4172	accuracy = 0.9560	loss = 0.1691	val_accuracy = 0.9683	val_loss = 0.1179	final_step = 4060
# patience_counter = 4
# step = 4200	accuracy = 0.9563	loss = 0.1703	val_accuracy = 0.9699	val_loss = 0.1169	final_step = 4060
# patience_counter = 0
# step = 4228	accuracy = 0.9558	loss = 0.1682	val_accuracy = 0.9701	val_loss = 0.1173	final_step = 4060
# patience_counter = 0
# step = 4256	accuracy = 0.9557	loss = 0.1677	val_accuracy = 0.9701	val_loss = 0.1177	final_step = 4060
# patience_counter = 0
# step = 4284	accuracy = 0.9557	loss = 0.1719	val_accuracy = 0.9700	val_loss = 0.1166	final_step = 4060
# patience_counter = 0
# step = 4312	accuracy = 0.9572	loss = 0.1708	val_accuracy = 0.9682	val_loss = 0.1180	final_step = 4060
# patience_counter = 1
# step = 4340	accuracy = 0.9584	loss = 0.1690	val_accuracy = 0.9701	val_loss = 0.1170	final_step = 4060
# patience_counter = 0
# step = 4368	accuracy = 0.9561	loss = 0.1742	val_accuracy = 0.9684	val_loss = 0.1172	final_step = 4060
# patience_counter = 1
# step = 4396	accuracy = 0.9588	loss = 0.1673	val_accuracy = 0.9699	val_loss = 0.1165	final_step = 4060
# patience_counter = 0
# step = 4424	accuracy = 0.9585	loss = 0.1666	val_accuracy = 0.9682	val_loss = 0.1181	final_step = 4060
# patience_counter = 1
# step = 4452	accuracy = 0.9562	loss = 0.1701	val_accuracy = 0.9682	val_loss = 0.1179	final_step = 4060
# patience_counter = 2
# step = 4480	accuracy = 0.9582	loss = 0.1654	val_accuracy = 0.9701	val_loss = 0.1173	final_step = 4060
# patience_counter = 0
# step = 4508	accuracy = 0.9555	loss = 0.1689	val_accuracy = 0.9701	val_loss = 0.1172	final_step = 4060
# patience_counter = 0
# step = 4536	accuracy = 0.9570	loss = 0.1669	val_accuracy = 0.9699	val_loss = 0.1169	final_step = 4060
# patience_counter = 0
# step = 4564	accuracy = 0.9579	loss = 0.1666	val_accuracy = 0.9700	val_loss = 0.1171	final_step = 4060
# patience_counter = 1
# step = 4592	accuracy = 0.9576	loss = 0.1645	val_accuracy = 0.9682	val_loss = 0.1173	final_step = 4060
# patience_counter = 2
# step = 4620	accuracy = 0.9551	loss = 0.1718	val_accuracy = 0.9701	val_loss = 0.1173	final_step = 4060
# patience_counter = 0
# step = 4648	accuracy = 0.9567	loss = 0.1686	val_accuracy = 0.9701	val_loss = 0.1169	final_step = 4648
# patience_counter = 0
# step = 4676	accuracy = 0.9569	loss = 0.1734	val_accuracy = 0.9700	val_loss = 0.1168	final_step = 4648
# patience_counter = 0
# step = 4704	accuracy = 0.9574	loss = 0.1678	val_accuracy = 0.9701	val_loss = 0.1172	final_step = 4648
# patience_counter = 1
# step = 4732	accuracy = 0.9573	loss = 0.1679	val_accuracy = 0.9699	val_loss = 0.1168	final_step = 4648
# patience_counter = 0
# step = 4760	accuracy = 0.9574	loss = 0.1666	val_accuracy = 0.9700	val_loss = 0.1167	final_step = 4648
# patience_counter = 0
# step = 4788	accuracy = 0.9573	loss = 0.1711	val_accuracy = 0.9701	val_loss = 0.1166	final_step = 4648
# patience_counter = 0
# step = 4816	accuracy = 0.9559	loss = 0.1681	val_accuracy = 0.9699	val_loss = 0.1176	final_step = 4648
# patience_counter = 1
# step = 4844	accuracy = 0.9562	loss = 0.1689	val_accuracy = 0.9699	val_loss = 0.1168	final_step = 4648
# patience_counter = 0
# step = 4872	accuracy = 0.9574	loss = 0.1691	val_accuracy = 0.9701	val_loss = 0.1170	final_step = 4648
# patience_counter = 1
# step = 4900	accuracy = 0.9574	loss = 0.1689	val_accuracy = 0.9699	val_loss = 0.1169	final_step = 4648
# patience_counter = 0
# step = 4928	accuracy = 0.9591	loss = 0.1627	val_accuracy = 0.9700	val_loss = 0.1169	final_step = 4648
# patience_counter = 0
# step = 4956	accuracy = 0.9573	loss = 0.1704	val_accuracy = 0.9699	val_loss = 0.1174	final_step = 4648
# patience_counter = 1
# step = 4984	accuracy = 0.9576	loss = 0.1678	val_accuracy = 0.9700	val_loss = 0.1169	final_step = 4648
# patience_counter = 0
# step = 5012	accuracy = 0.9565	loss = 0.1683	val_accuracy = 0.9700	val_loss = 0.1172	final_step = 4648
# patience_counter = 1
# step = 5040	accuracy = 0.9568	loss = 0.1689	val_accuracy = 0.9699	val_loss = 0.1168	final_step = 4648
# patience_counter = 0
# step = 5068	accuracy = 0.9562	loss = 0.1682	val_accuracy = 0.9701	val_loss = 0.1161	final_step = 4648
# patience_counter = 0
# step = 5096	accuracy = 0.9574	loss = 0.1677	val_accuracy = 0.9699	val_loss = 0.1178	final_step = 4648
# patience_counter = 1

# %%
# !tensorboard --logdir logs
# Out:
# NOTE: Using experimental fast data loading logic. To disable, pass
#     "--load_fast=false" and report issues on GitHub. More details:
#     https://github.com/tensorflow/tensorboard/issues/4784
#
# Serving TensorBoard on localhost; to expose to the network, use a proxy or pass --bind_all
# TensorBoard 2.8.0 at http://localhost:6006/ (Press CTRL+C to quit)
# ^C

# %%
preds = predict(test_index)
print('F1 Score: ', f1_score(graph.y[test_index], preds),
      '\n Accuracy Score: ', accuracy_score(graph.y[test_index], preds),
     '\n Predictions were: ', sorted(Counter(np.array(preds)).items()),
     '\n Actual Results: ', sorted(Counter(np.array(graph.y[test_index])).items()))
# Out:
# F1 Score:  0.36363636363636365
#  Accuracy Score:  0.997546442341395
#  Predictions were:  [(0, 11397), (1, 15)]
#  Actual Results:  [(0, 11383), (1, 29)]

# %%
# Finding number of false positives
false_scam = len(preds[(preds != graph.y[test_index]) & (preds == 1)])

print((false_scam / len(preds[(preds == 1)]))*100, '% of scam predictions were incorrect.')
# Out:
# 46.666666666666664 % of scam predictions were incorrect.

# %%
transform = TSNE

node_reps = model.gcn4([model.gcn0([graph.x, edge_Index, edge_Weight]), edge_Index, edge_Weight])
X_reps = tf.keras.backend.get_value(node_reps)
trans = transform(n_components = 2, perplexity=50)
X_reps = trans.fit_transform(X_reps)

X_reps.shape
# Out:
# (73034, 2)

# %%
X_pd = pd.DataFrame({'X_0':X_reps[:,0],
                     'X_1':X_reps[:,1],
                    'y':y_new})

X_non = X_pd[X_pd['y']==0]

X_scam = X_pd[X_pd['y']==1]

fig, ax = plt.subplots(figsize=(10,10))

ax.scatter(X_non['X_0'],
           X_non['X_1'],
          c=plt.cm.Set3(0),
          alpha=0.5)
ax.scatter(X_scam['X_0'],
           X_scam['X_1'],
          c=plt.cm.Set3(plt.cm.Set3.N),
          alpha=0.75)

ax.set(aspect='equal',
      xlabel='X_1',
      ylabel='X_2',)

plt.savefig('TSNE_ETH.jpeg')
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %% [markdown]
# # GCN ERC-1155

# %% [markdown]
# #### ERC1155 Dataset

# %%
# Removing all transactions with the null_address 0x0000000000000000000000000000000000000000

df_erc1155 = (df_erc1155 >> mask(X.from_address != '0x0000000000000000000000000000000000000000', 
                              X.to_address != '0x0000000000000000000000000000000000000000'))

# %%
#Convert block_timestamp to timestamps
df_erc1155['timeStamp'] = pd.to_datetime(df_erc1155['timeStamp']).astype(int)

# For every from_address, collect the timestamps
adr_timestamp_1155 = (df_erc1155 >> select(X.from_address, X.timeStamp) >>
mutate(timestamps = X.timeStamp) >> #(X.block_timestamp).to_numpy(dtype = np.float32)) >>
select(~X.timeStamp))

adr_timestamp_1155 = (adr_timestamp_1155 >> group_by(X.from_address) >>
summarize(min_timestamp = X.timestamps.min(),
      max_timestamp = (X.timestamps).max(),
      med_timestamp = (X.timestamps).median(),
      mean_timestamp = (X.timestamps).mean()))


# For every from_address, collect the reciept_gas/gas_used
adr_gas_1155 = (df_erc1155 >> select(X.from_address, X.gas) >>
mutate(gas_used = (X.gas).to_numpy(dtype = np.float32)) >>
select(~X.gas))
                
adr_gas_1155 = (adr_gas_1155 >> group_by(X.from_address) >>
summarize(min_gas = X.gas_used.min(),
      max_gas = (X.gas_used).max(),
      med_gas = (X.gas_used).median(),
      mean_gas = (X.gas_used).mean()))


# For every from_address, count the number of transactions made
outgoing_count_1155 = (df_erc1155 >> select(X.from_address) >> 
group_by(X.from_address) >> summarize(out_count = (X.from_address).count()))


# For every from_address, count the number of incoming transactions
incoming_count_1155 = (df_erc1155 >> select(X.to_address) >> 
group_by(X.to_address) >> summarize(in_count = (X.to_address).count()))

# For every from_address, calculate the value of outgoing transactions
outgoing_val_1155 = (df_erc1155 >> select(X.from_address, X.priceETH) >>
mutate(outgoing_priceETH = (X.priceETH).to_numpy(dtype = np.float32)) >>
select(~X.priceETH))
                
outgoing_val_1155 = (outgoing_val_1155 >> group_by(X.from_address) >>
summarize(min_outgoing_priceETH = X.outgoing_priceETH.min(), #>>
      max_outgoing_priceETH = (X.outgoing_priceETH).max(),
      med_outgoing_priceETH = (X.outgoing_priceETH).median(),
      mean_outgoing_priceETH = (X.outgoing_priceETH).mean()))# >>

# For every to_address, calculate the value of incoming transactions
incoming_val_1155 = (df_erc1155 >> select(X.to_address, X.priceETH) >>
mutate(incoming_priceETH = (X.priceETH).to_numpy(dtype = np.float32)) >>
select(~X.priceETH))
                
incoming_val_1155 = (incoming_val_1155 >> group_by(X.to_address) >>
summarize(min_incoming_priceETH = X.incoming_priceETH.min(), #>>
      max_incoming_priceETH = (X.incoming_priceETH).max(),
      med_incoming_priceETH = (X.incoming_priceETH).median(),
      mean_incoming_priceETH = (X.incoming_priceETH).mean())) #>>

# %%
G_1155 =  nx.from_pandas_edgelist(df = df_erc1155, source='from_address', 
                                        target='to_address',
                                        edge_attr = ['transaction_hash', 'transaction_index', 
                                         'priceETH', 'timeStamp', 'block_number', 'gas_price',
                                         'receipt_gas_used'],
                                       create_using = nx.DiGraph())

df_nodes_1155 = pd.DataFrame({'node_id': G_1155.nodes})

df_eig_centrality_1155 = pd.DataFrame.from_dict(nx.eigenvector_centrality_numpy(G_1155), orient='index').reset_index()
df_eig_centrality_1155.rename(columns={'index':'node_id', 0:'eigenvector_centrality'}, inplace=True)

df_pangerank_1155 = pd.DataFrame.from_dict(nx.pagerank(G_1155), orient='index').reset_index()
df_pangerank_1155.rename(columns={'index':'node_id', 0:'pagerank'}, inplace=True)

df_in_degree_1155 = pd.DataFrame.from_dict(dict(G.in_degree(G_1155.nodes)), orient='index').reset_index()
df_in_degree_1155.rename(columns={'index':'node_id', 0:'in_degree'}, inplace=True)

df_out_degree_1155 = pd.DataFrame.from_dict(dict(G.out_degree(G_1155.nodes)), orient='index').reset_index()
df_out_degree_1155.rename(columns={'index':'node_id', 0:'out_degree'}, inplace=True)

df_nodes_1155 = df_nodes.merge(df_eig_centrality_1155, on='node_id')
df_nodes_1155 = df_nodes.merge(df_pangerank_1155, on='node_id')
df_nodes_1155 = df_nodes.merge(df_in_degree_1155, on='node_id')
df_nodes_1155 = df_nodes.merge(df_out_degree_1155, on='node_id')

df_nodes_1155 = (df_nodes_1155 >> select(~X.out_degree_y) >>
mutate(out_degree = X.out_degree_x) >>
select(~X.out_degree_x))

#print(df_nodes_1155.columns)

# %%
######## Creating Node Feature Matrix X ########

feature_matrix_1 = pd.merge(adr_timestamp_1155, adr_gas_1155, how = 'outer', on = 'from_address')
feature_matrix_2 = pd.merge(outgoing_count_1155, outgoing_val_1155, how = 'outer', on = 'from_address')
feature_matrix_3 = pd.merge(feature_matrix_1, feature_matrix_2, how = 'outer', on = 'from_address')

feature_matrix_4 = pd.merge(incoming_count_1155, incoming_val_1155, how = 'outer', on = 'to_address')

feature_matrix_1155 = pd.merge(feature_matrix_3, feature_matrix_4, how = 'outer', 
                          left_on = 'from_address', right_on = 'to_address')

feature_matrix_1155['address'] = feature_matrix_1155['from_address'].fillna(feature_matrix_1155['to_address'])

feature_matrix_1155 = pd.merge(feature_matrix_1155, df_nodes_1155, how = 'outer', 
                          left_on = 'address', right_on = 'node_id')
print(feature_matrix_1155.columns)

feature_matrix_1155 = (feature_matrix_1155 >> select(~X.to_address, ~X.from_address, 
                                                     ~X.node_id))
feature_matrix_1155 = feature_matrix_1155.drop_duplicates(subset = 'address')
# Out:
# Index(['from_address', 'min_timestamp', 'max_timestamp', 'med_timestamp',
#        'mean_timestamp', 'min_gas', 'max_gas', 'med_gas', 'mean_gas',
#        'out_count', 'min_outgoing_priceETH', 'max_outgoing_priceETH',
#        'med_outgoing_priceETH', 'mean_outgoing_priceETH', 'to_address',
#        'in_count', 'min_incoming_priceETH', 'max_incoming_priceETH',
#        'med_incoming_priceETH', 'mean_incoming_priceETH', 'address', 'node_id',
#        'eigenvector_centrality', 'pagerank', 'in_degree', 'out_degree'],
#       dtype='object')

# %%
# Randomly sample instances to create a small training set

#train_index = np.random.randint(0, high = len(feature_matrix_1155), size = 1500, dtype=int)

#train_addresses = feature_matrix_1155.iloc[train_index]

#train_addresses['label'] = ['unlabeled' for i in range(len(train_addresses))]


# Label the instances

#for adr in train_addresses['address']:

#    adr_http = 'https://etherscan.io/address/' + adr
#    req = Request(adr_http,  
#              headers={'User-Agent': 'Mozilla/5.0'})
#    page = urlopen(req)
#    content = page.read()

#    soup = BeautifulSoup(content)

#    label = soup.findAll('div', attrs = {'class':'mt-1'})
#    if len(label) > 1:
#        label = label[1]
#        rows = label.findAll('a')
#        if len(rows) == 0:
#            train_addresses.loc[train_addresses['address'] == adr, 'label'] = 'None'
#        else:
#            for row in rows:
#                train_addresses.loc[train_addresses['address'] == adr, 'label'] = row.text
#    else:
#        train_addresses.loc[train_addresses['address'] == adr, 'label'] = 'None'

# %%
#print(sorted(Counter(train_addresses['label']).items()))

#train_addresses.to_csv('data/train_addresses_ERC1155.csv')

train_addresses = pd.read_csv('data/train_addresses_ERC1155.csv')

# %%
label_dict = {'Gitcoin Grantee ': 0, 'None': 0, 'Snapshot Voter': 0, 
              'Take Action ': 0}
              
labels = [label_dict[x] for x in train_addresses['label']]
    
train_addresses['label'] = labels

# %%
train_data = train_addresses >> select(~X.label)

train_index_ERC1155 = list()

for adr in train_data['address']:
    train_index_ERC1155.append(feature_matrix_1155.index[feature_matrix_1155['address'] == adr][0])

# %%
indeces_ERC1155 = list(np.arange(len(feature_matrix_1155)))

test_index_ERC1155 = list()

for ind in indeces_ERC1155:
    if ind not in train_index_ERC1155:
        test_index_ERC1155.append(ind)

# %%
######## Creating Adjacency Matrix A (edge_index, edge_weight) ########


adr_ind_dict = dict(zip(feature_matrix_1155['address'], np.arange(len(feature_matrix_1155['address']))))

edge_Index_1 = [adr_ind_dict[adr] for adr in df_erc1155['from_address']]
edge_Index_2 = [adr_ind_dict[adr] for adr in df_erc1155['to_address']]

#############################

edge_Index = np.array([edge_Index_1, edge_Index_2])


edge_Weight = np.zeros(len(edge_Index_1))
#np.array(df_erc1155['priceETH'], dtype=np.float32)

#A = (edge_Index, edge_Weight)

edge_Index.shape, edge_Weight.shape
# Out:
# ((2, 207192), (207192,))

# %%
# Drop the address column from X
X_feats = feature_matrix_1155 >> select(~X.address)

# %%
# Converting feature matrix to useable form for graph
X_feats.fillna(-1, inplace=True)
X_feats = np.asarray(X_feats)

# Normalize according to training data

#X_min = np.min(X_feats[train_index_ERC1155], axis=0)
X_feats -= X_min
#X_max = np.max(X_feats[train_index_ERC1155], axis=0)
X_feats /= X_max - X_min


#X_feats = np.asarray(X_feats)
X_feats = np.reshape(X_feats, (len(X_feats),-1))

# %%
ERC1155_Graph = tfg.Graph(x = X_feats,
                          y = train_addresses['label'],
                        edge_index = edge_Index,
                        edge_weight = edge_Weight).to_directed()

# %%
## Chop off 'head' of GCN and utilized with new ERC1155 dataset

patience = 5

num_classes = 2
drop_rate = 0.25 #0.25
l2_coef = 5e-3

# Multi-layer GCN Model
class GCN_TL(keras.Model):

    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.gcn0 = tfg.layers.GCN(12, activation=tf.nn.relu, improved = True,
                                    edge_drop_rate = drop_rate,
                                   renorm = True) # relu
        
        self.gcn4 = tfg.layers.GCN(8, activation = tf.nn.relu, improved = True,
                                  edge_drop_rate = drop_rate) 

        self.dense = tf.keras.layers.Dense(2, )
        
    def call(self, inputs, training=None, mask=None, cache=None):
        x, edge_index, edge_weight = inputs
        h = self.gcn0([x, edge_index, edge_weight], training = training, cache=cache)
        h = self.gcn4([h, edge_index, edge_weight], training = training, cache=cache)
        h = self.dense(h, training = training)
        
        #self.gcn0.set_weights(ETH_model.gcn0.get_weights()) #shape (18, 19)
        #self.gcn4.set_weights(ETH_model.gcn4.get_weights())
        self.dense.set_weights(ETH_model.dense.get_weights())
        
        self.gcn0.trainable = True
        self.gcn4.trainable = True
        self.dense.trainable = False
        
        return h


erc1155_model = GCN_TL()
erc1155_model.gcn0.build_cache_for_graph(ERC1155_Graph)

optimizer = tf.keras.optimizers.Adamax(learning_rate = 0.006)#0.0075 )

erc1155_model.compile(optimizer = optimizer,)

# %%
model = erc1155_model
graph = ERC1155_Graph
train_index = train_index_ERC1155
valid_index = train_index_ERC1155
test_index = test_index_ERC1155

# %%
val_accuracy_list = []
loss_list = []

best_val_accuracy = 0
min_val_loss = 1000

final_step = None

patience_counter = 0

num_steps = 5121 #25601

for step in range(1, num_steps):

    accuracy, loss = train_step()

    if step % 28 == 0:
        val_accuracy, (_, val_loss, _) = evaluate_val()
        val_accuracy = val_accuracy
        val_loss = val_loss.numpy()

        if val_accuracy > best_val_accuracy or val_loss < min_val_loss:
            patience_counter = 0
        else:
            patience_counter += 1
            if patience_counter > patience:
                break

        if val_accuracy > best_val_accuracy and val_loss < min_val_loss:
            final_step = step

            best_val_accuracy = val_accuracy
            min_val_loss = val_loss

        val_accuracy_list.append(val_accuracy)
        loss_list.append(val_loss)

        print("step = {}\taccuracy = {:.4f}\tloss = {:.4f}\tval_accuracy = {:.4f}\tval_loss = {:.4f}\tfinal_step = {}"
            .format(step, accuracy, loss, val_accuracy, val_loss, final_step))       
        print("patience_counter = {}".format(patience_counter))
# Out:
# step = 28	accuracy = 0.9569	loss = 0.1665	val_accuracy = 0.9699	val_loss = 0.1171	final_step = 28
# patience_counter = 0
# step = 56	accuracy = 0.9582	loss = 0.1702	val_accuracy = 0.9701	val_loss = 0.1176	final_step = 28
# patience_counter = 0
# step = 84	accuracy = 0.9562	loss = 0.1689	val_accuracy = 0.9698	val_loss = 0.1165	final_step = 28
# patience_counter = 0
# step = 112	accuracy = 0.9584	loss = 0.1663	val_accuracy = 0.9700	val_loss = 0.1166	final_step = 112
# patience_counter = 0
# step = 140	accuracy = 0.9561	loss = 0.1663	val_accuracy = 0.9701	val_loss = 0.1174	final_step = 112
# patience_counter = 0
# step = 168	accuracy = 0.9563	loss = 0.1688	val_accuracy = 0.9699	val_loss = 0.1167	final_step = 112
# patience_counter = 1
# step = 196	accuracy = 0.9546	loss = 0.1644	val_accuracy = 0.9699	val_loss = 0.1178	final_step = 112
# patience_counter = 2
# step = 224	accuracy = 0.9567	loss = 0.1693	val_accuracy = 0.9699	val_loss = 0.1179	final_step = 112
# patience_counter = 3
# step = 252	accuracy = 0.9577	loss = 0.1665	val_accuracy = 0.9699	val_loss = 0.1167	final_step = 112
# patience_counter = 4
# step = 280	accuracy = 0.9556	loss = 0.1725	val_accuracy = 0.9699	val_loss = 0.1165	final_step = 112
# patience_counter = 0
# step = 308	accuracy = 0.9549	loss = 0.1730	val_accuracy = 0.9700	val_loss = 0.1171	final_step = 112
# patience_counter = 1
# step = 336	accuracy = 0.9575	loss = 0.1647	val_accuracy = 0.9699	val_loss = 0.1165	final_step = 112
# patience_counter = 0
# step = 364	accuracy = 0.9575	loss = 0.1681	val_accuracy = 0.9700	val_loss = 0.1174	final_step = 112
# patience_counter = 1
# step = 392	accuracy = 0.9551	loss = 0.1706	val_accuracy = 0.9699	val_loss = 0.1172	final_step = 112
# patience_counter = 2
# step = 420	accuracy = 0.9580	loss = 0.1678	val_accuracy = 0.9700	val_loss = 0.1179	final_step = 112
# patience_counter = 3
# step = 448	accuracy = 0.9593	loss = 0.1609	val_accuracy = 0.9700	val_loss = 0.1169	final_step = 112
# patience_counter = 4
# step = 476	accuracy = 0.9581	loss = 0.1628	val_accuracy = 0.9699	val_loss = 0.1176	final_step = 112
# patience_counter = 5
# step = 504	accuracy = 0.9572	loss = 0.1652	val_accuracy = 0.9699	val_loss = 0.1159	final_step = 112
# patience_counter = 0
# step = 532	accuracy = 0.9559	loss = 0.1700	val_accuracy = 0.9701	val_loss = 0.1177	final_step = 112
# patience_counter = 0
# step = 560	accuracy = 0.9581	loss = 0.1626	val_accuracy = 0.9699	val_loss = 0.1176	final_step = 112
# patience_counter = 1
# step = 588	accuracy = 0.9578	loss = 0.1705	val_accuracy = 0.9700	val_loss = 0.1169	final_step = 112
# patience_counter = 2
# step = 616	accuracy = 0.9566	loss = 0.1682	val_accuracy = 0.9701	val_loss = 0.1170	final_step = 112
# patience_counter = 0
# step = 644	accuracy = 0.9580	loss = 0.1664	val_accuracy = 0.9701	val_loss = 0.1167	final_step = 112
# patience_counter = 0
# step = 672	accuracy = 0.9567	loss = 0.1650	val_accuracy = 0.9699	val_loss = 0.1161	final_step = 112
# patience_counter = 0
# step = 700	accuracy = 0.9584	loss = 0.1626	val_accuracy = 0.9699	val_loss = 0.1162	final_step = 112
# patience_counter = 0
# step = 728	accuracy = 0.9570	loss = 0.1655	val_accuracy = 0.9699	val_loss = 0.1165	final_step = 112
# patience_counter = 0
# step = 756	accuracy = 0.9567	loss = 0.1665	val_accuracy = 0.9701	val_loss = 0.1173	final_step = 112
# patience_counter = 0
# step = 784	accuracy = 0.9578	loss = 0.1640	val_accuracy = 0.9698	val_loss = 0.1163	final_step = 112
# patience_counter = 0
# step = 812	accuracy = 0.9577	loss = 0.1686	val_accuracy = 0.9701	val_loss = 0.1188	final_step = 112
# patience_counter = 0
# step = 840	accuracy = 0.9546	loss = 0.1695	val_accuracy = 0.9699	val_loss = 0.1168	final_step = 112
# patience_counter = 1
# step = 868	accuracy = 0.9579	loss = 0.1666	val_accuracy = 0.9700	val_loss = 0.1167	final_step = 112
# patience_counter = 2
# step = 896	accuracy = 0.9556	loss = 0.1709	val_accuracy = 0.9694	val_loss = 0.1166	final_step = 112
# patience_counter = 3
# step = 924	accuracy = 0.9556	loss = 0.1715	val_accuracy = 0.9701	val_loss = 0.1173	final_step = 112
# patience_counter = 0
# step = 952	accuracy = 0.9554	loss = 0.1625	val_accuracy = 0.9701	val_loss = 0.1175	final_step = 112
# patience_counter = 0
# step = 980	accuracy = 0.9572	loss = 0.1717	val_accuracy = 0.9701	val_loss = 0.1169	final_step = 112
# patience_counter = 0
# step = 1008	accuracy = 0.9585	loss = 0.1727	val_accuracy = 0.9700	val_loss = 0.1163	final_step = 112
# patience_counter = 0
# step = 1036	accuracy = 0.9569	loss = 0.1656	val_accuracy = 0.9697	val_loss = 0.1165	final_step = 112
# patience_counter = 0
# step = 1064	accuracy = 0.9562	loss = 0.1699	val_accuracy = 0.9701	val_loss = 0.1175	final_step = 112
# patience_counter = 0
# step = 1092	accuracy = 0.9596	loss = 0.1636	val_accuracy = 0.9699	val_loss = 0.1165	final_step = 112
# patience_counter = 0
# step = 1120	accuracy = 0.9568	loss = 0.1688	val_accuracy = 0.9698	val_loss = 0.1175	final_step = 112
# patience_counter = 1
# step = 1148	accuracy = 0.9580	loss = 0.1661	val_accuracy = 0.9699	val_loss = 0.1157	final_step = 112
# patience_counter = 0
# step = 1176	accuracy = 0.9551	loss = 0.1710	val_accuracy = 0.9701	val_loss = 0.1168	final_step = 112
# patience_counter = 0
# step = 1204	accuracy = 0.9554	loss = 0.1707	val_accuracy = 0.9701	val_loss = 0.1174	final_step = 112
# patience_counter = 0
# step = 1232	accuracy = 0.9564	loss = 0.1681	val_accuracy = 0.9701	val_loss = 0.1179	final_step = 112
# patience_counter = 0
# step = 1260	accuracy = 0.9577	loss = 0.1667	val_accuracy = 0.9699	val_loss = 0.1169	final_step = 112
# patience_counter = 1
# step = 1288	accuracy = 0.9580	loss = 0.1671	val_accuracy = 0.9698	val_loss = 0.1164	final_step = 112
# patience_counter = 0
# step = 1316	accuracy = 0.9560	loss = 0.1664	val_accuracy = 0.9699	val_loss = 0.1171	final_step = 112
# patience_counter = 1
# step = 1344	accuracy = 0.9563	loss = 0.1679	val_accuracy = 0.9701	val_loss = 0.1172	final_step = 112
# patience_counter = 0
# step = 1372	accuracy = 0.9567	loss = 0.1676	val_accuracy = 0.9696	val_loss = 0.1152	final_step = 112
# patience_counter = 0
# step = 1400	accuracy = 0.9596	loss = 0.1652	val_accuracy = 0.9701	val_loss = 0.1183	final_step = 112
# patience_counter = 0
# step = 1428	accuracy = 0.9590	loss = 0.1625	val_accuracy = 0.9699	val_loss = 0.1164	final_step = 112
# patience_counter = 0
# step = 1456	accuracy = 0.9580	loss = 0.1691	val_accuracy = 0.9700	val_loss = 0.1172	final_step = 112
# patience_counter = 1
# step = 1484	accuracy = 0.9580	loss = 0.1733	val_accuracy = 0.9701	val_loss = 0.1180	final_step = 112
# patience_counter = 0
# step = 1512	accuracy = 0.9570	loss = 0.1678	val_accuracy = 0.9699	val_loss = 0.1159	final_step = 112
# patience_counter = 0
# step = 1540	accuracy = 0.9574	loss = 0.1673	val_accuracy = 0.9696	val_loss = 0.1165	final_step = 112
# patience_counter = 0
# step = 1568	accuracy = 0.9565	loss = 0.1722	val_accuracy = 0.9700	val_loss = 0.1168	final_step = 112
# patience_counter = 1
# step = 1596	accuracy = 0.9582	loss = 0.1634	val_accuracy = 0.9701	val_loss = 0.1179	final_step = 112
# patience_counter = 0
# step = 1624	accuracy = 0.9589	loss = 0.1657	val_accuracy = 0.9701	val_loss = 0.1173	final_step = 112
# patience_counter = 0
# step = 1652	accuracy = 0.9577	loss = 0.1682	val_accuracy = 0.9696	val_loss = 0.1160	final_step = 112
# patience_counter = 0
# step = 1680	accuracy = 0.9584	loss = 0.1713	val_accuracy = 0.9696	val_loss = 0.1169	final_step = 112
# patience_counter = 1
# step = 1708	accuracy = 0.9588	loss = 0.1634	val_accuracy = 0.9699	val_loss = 0.1161	final_step = 112
# patience_counter = 0
# step = 1736	accuracy = 0.9572	loss = 0.1664	val_accuracy = 0.9701	val_loss = 0.1177	final_step = 112
# patience_counter = 0
# step = 1764	accuracy = 0.9590	loss = 0.1624	val_accuracy = 0.9701	val_loss = 0.1174	final_step = 112
# patience_counter = 0
# step = 1792	accuracy = 0.9576	loss = 0.1654	val_accuracy = 0.9699	val_loss = 0.1169	final_step = 112
# patience_counter = 1
# step = 1820	accuracy = 0.9570	loss = 0.1644	val_accuracy = 0.9700	val_loss = 0.1167	final_step = 112
# patience_counter = 2
# step = 1848	accuracy = 0.9576	loss = 0.1668	val_accuracy = 0.9701	val_loss = 0.1174	final_step = 112
# patience_counter = 0
# step = 1876	accuracy = 0.9592	loss = 0.1688	val_accuracy = 0.9701	val_loss = 0.1171	final_step = 112
# patience_counter = 0
# step = 1904	accuracy = 0.9582	loss = 0.1657	val_accuracy = 0.9701	val_loss = 0.1165	final_step = 1904
# patience_counter = 0
# step = 1932	accuracy = 0.9585	loss = 0.1643	val_accuracy = 0.9698	val_loss = 0.1176	final_step = 1904
# patience_counter = 1
# step = 1960	accuracy = 0.9588	loss = 0.1666	val_accuracy = 0.9700	val_loss = 0.1167	final_step = 1904
# patience_counter = 2
# step = 1988	accuracy = 0.9573	loss = 0.1621	val_accuracy = 0.9701	val_loss = 0.1176	final_step = 1904
# patience_counter = 3
# step = 2016	accuracy = 0.9573	loss = 0.1684	val_accuracy = 0.9699	val_loss = 0.1166	final_step = 1904
# patience_counter = 4
# step = 2044	accuracy = 0.9571	loss = 0.1645	val_accuracy = 0.9696	val_loss = 0.1163	final_step = 1904
# patience_counter = 0
# step = 2072	accuracy = 0.9586	loss = 0.1673	val_accuracy = 0.9701	val_loss = 0.1168	final_step = 1904
# patience_counter = 1
# step = 2100	accuracy = 0.9537	loss = 0.1745	val_accuracy = 0.9700	val_loss = 0.1169	final_step = 1904
# patience_counter = 2
# step = 2128	accuracy = 0.9573	loss = 0.1684	val_accuracy = 0.9698	val_loss = 0.1165	final_step = 1904
# patience_counter = 3
# step = 2156	accuracy = 0.9569	loss = 0.1700	val_accuracy = 0.9696	val_loss = 0.1161	final_step = 1904
# patience_counter = 0
# step = 2184	accuracy = 0.9582	loss = 0.1673	val_accuracy = 0.9701	val_loss = 0.1169	final_step = 1904
# patience_counter = 1
# step = 2212	accuracy = 0.9563	loss = 0.1726	val_accuracy = 0.9701	val_loss = 0.1179	final_step = 1904
# patience_counter = 2
# step = 2240	accuracy = 0.9555	loss = 0.1696	val_accuracy = 0.9700	val_loss = 0.1163	final_step = 1904
# patience_counter = 0
# step = 2268	accuracy = 0.9570	loss = 0.1650	val_accuracy = 0.9701	val_loss = 0.1176	final_step = 1904
# patience_counter = 1
# step = 2296	accuracy = 0.9573	loss = 0.1701	val_accuracy = 0.9700	val_loss = 0.1185	final_step = 1904
# patience_counter = 2
# step = 2324	accuracy = 0.9592	loss = 0.1647	val_accuracy = 0.9701	val_loss = 0.1169	final_step = 1904
# patience_counter = 3
# step = 2352	accuracy = 0.9570	loss = 0.1689	val_accuracy = 0.9698	val_loss = 0.1173	final_step = 1904
# patience_counter = 4
# step = 2380	accuracy = 0.9553	loss = 0.1688	val_accuracy = 0.9695	val_loss = 0.1165	final_step = 1904
# patience_counter = 5

# %%
# Running model with weights equal to the layers in the ERC20 model
logits = erc1155_model([X_feats, edge_Index, edge_Weight], 
                 training = False, cache = ERC1155_Graph.cache)
logits = erc1155_model([X_feats, edge_Index, edge_Weight], 
                 training = False, cache = ERC1155_Graph.cache)

masked_logits = tf.gather(logits, test_index)
y_pred = tf.argmax(masked_logits, axis=-1, output_type=tf.int32)

sorted(Counter(np.array(y_pred)).items())
# Out:
# [(0, 112942), (1, 32)]

# %%
transform = TSNE

node_reps_erc1155 = model.gcn4([model.gcn0([graph.x, edge_Index, edge_Weight]), edge_Index, edge_Weight])
X_reps_erc1155 = tf.keras.backend.get_value(node_reps_erc1155)
trans = transform(n_components = 2, perplexity=50)
X_reps_erc1155 = trans.fit_transform(X_reps_erc1155)

X_reps_erc1155.shape
# Out:
# (114467, 2)

# %%
logits = erc1155_model([X_feats, edge_Index, edge_Weight], 
                 training = False, cache = graph.cache)

masked_logits = tf.gather(logits, np.arange(len(logits)))
y_preds = tf.argmax(masked_logits, axis=-1, output_type=tf.int32)

# %%
X_pd = pd.DataFrame({'X_0':X_reps_erc1155[:,0],
                     'X_1':X_reps_erc1155[:,1],
                    'y':y_preds})

X_non = X_pd[X_pd['y']==0]

X_scam = X_pd[X_pd['y']==1]

fig, ax = plt.subplots(figsize=(10,10))

ax.scatter(X_non['X_0'],
           X_non['X_1'],
          c=plt.cm.Set3(0),
          alpha=0.5)
ax.scatter(X_scam['X_0'],
           X_scam['X_1'],
          c=plt.cm.Set3(plt.cm.Set3.N),
          alpha=0.75)

ax.set(aspect='equal',
      xlabel='X_1',
      ylabel='X_2',)

#plt.savefig('TSNE_ERC1155.jpeg')
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
# Research the predicted scam addresses
scam_indices = np.asarray([y_pred == 1])[0]

scam_ind = [test_index_ERC1155[i] for i in range(len(test_index_ERC1155)) if scam_indices[i]]

ERC1155_scams = pd.DataFrame({'address': feature_matrix_1155['address'][scam_ind]})

#ERC1155_scams.to_csv('data/ERC1155_scams.csv')

# %%
#ERC1155_scams

# %%
ERC1155_scam_preds = pd.DataFrame({'address': ERC1155_scams['address'],
                                  'predicted_count': list(np.ones(len(ERC1155_scams['address'])))})
patience = 7
steps = 4
i = 0
j = 0
while (i < steps):
    ERC1155_Graph = tfg.Graph(x = X_feats,
                        edge_index = edge_Index,
                        edge_weight = edge_Weight).to_directed()
    erc1155_model = GCN_TL()
    erc1155_model.gcn0.build_cache_for_graph(ERC1155_Graph)
    
    optimizer = tf.keras.optimizers.Adamax(learning_rate = 0.006)#0.0075 )

    erc1155_model.compile(optimizer = optimizer)
    
    model = erc1155_model
    graph = ERC1155_Graph
    train_index = train_index_ERC1155
    valid_index = train_index_ERC1155
    test_index = test_index_ERC1155
    
    print('\nTraining...')
    for step in range(1, num_steps):

        accuracy, loss = train_step()

        if step % 28 == 0:
            val_accuracy, (_, val_loss, _) = evaluate_val()
            val_accuracy = val_accuracy
            val_loss = val_loss.numpy()

            if val_accuracy > best_val_accuracy or val_loss < min_val_loss:
                patience_counter = 0
            else:
                patience_counter += 1
                if patience_counter > patience:
                    break

            if val_accuracy > best_val_accuracy and val_loss < min_val_loss:
                final_step = step

                best_val_accuracy = val_accuracy
                min_val_loss = val_loss

            val_accuracy_list.append(val_accuracy)
            loss_list.append(val_loss)


    # Initializing the model in order to set weights to the ERC20 model weights
    erc1155_model([X_feats, edge_Index, edge_Weight], 
                 training = False, cache = graph.cache)
    # Running model with weights equal to the layers in the ERC20 model
    logits = erc1155_model([X_feats, edge_Index, edge_Weight], 
                 training = False, cache = graph.cache)

    masked_logits = tf.gather(logits, np.arange(len(X_feats)))
    y_pred = tf.argmax(masked_logits, axis=-1, output_type=tf.int32)
    
    # Research the predicted scam addresses
    scam_indices = np.asarray([y_pred == 1])[0]

    scam_ind = [test_index_ERC1155[i] for i in range(len(test_index_ERC1155)) if scam_indices[i]]

    ERC1155_scams = pd.DataFrame({'address': feature_matrix_1155['address'][scam_ind]})
    
    print('Number of predicted scams: ', len(ERC1155_scams))
    
    if len(ERC1155_scams) < 15000 and len(ERC1155_scams) > 0:
        print('Index: ', i+1, ' / ', steps)
        #print('Number of predicted scams: ', len(ERC1155_scams))
        
        new_scams = [new for new in ERC1155_scams['address'] if ERC1155_scam_preds[ERC1155_scam_preds['address'] == new].empty]
        repeat_scam = [old for old in ERC1155_scams['address'] if not ERC1155_scam_preds[ERC1155_scam_preds['address'] == old].empty]
        print('Number of repeat predicted scams: ', len(repeat_scam))
    
        ERC1155_scam_preds = ERC1155_scam_preds.append(pd.DataFrame({'address':new_scams, 'predicted_count':np.ones(len(new_scams))}))
    
        for scam in repeat_scam:
            ERC1155_scam_preds.loc[ERC1155_scam_preds['address'] == scam, 'predicted_count'] = ERC1155_scam_preds[ERC1155_scam_preds['address'] == scam]['predicted_count'] + 1
        i = i + 1
        j = 0
    else:
        j = j + 1
        print('Last training step: ', step)
        continue
    if j == 2*steps:
        print('Error. Taking too long.')
        break
# Out:
# Training...
# Number of predicted scams:  30
# Index:  1  /  4
# Number of repeat predicted scams:  30
#
# Training...
# Number of predicted scams:  21
# Index:  2  /  4
# Number of repeat predicted scams:  21
#
# Training...
# Number of predicted scams:  31
# Index:  3  /  4
# Number of repeat predicted scams:  30
#
# Training...
# Number of predicted scams:  30
# Index:  4  /  4
# Number of repeat predicted scams:  30

# %%
print(len(ERC1155_scam_preds))

ERC1155_scam_preds = ERC1155_scam_preds.sort_values('predicted_count', ascending = False, ignore_index = True)
min_count = min(ERC1155_scam_preds['predicted_count'])
max_count = max(ERC1155_scam_preds['predicted_count'])

ERC1155_scam_preds_top = ERC1155_scam_preds
while len(ERC1155_scam_preds_top) > 1600:
    ERC1155_scam_preds_top = ERC1155_scam_preds[ERC1155_scam_preds['predicted_count'] > (min_count)]
    min_count = min_count + 1
if len(ERC1155_scam_preds_top) == 0:
    #ERC1155_scam_preds_top = ERC1155_scam_preds[ERC1155_scam_preds['predicted_count'] == max_count]
    ERC1155_scam_preds_top = ERC1155_scam_preds.iloc[range(int(len(ERC1155_scam_preds)*0.1))]



print(len(ERC1155_scam_preds_top))
# Out:
# 32
# 32

# %% [markdown]
# ### Retrying GCN with help from OpenWGL

# %%
ERC1155_scam_preds_top['label'] = ['unlabeled' for i in range(len(ERC1155_scam_preds_top))]

# %%
ERC1155_scam_preds_top[ERC1155_scam_preds_top['address'] == '0x8010d5c63d426c5809ab05ce27493e21b7022be0']
# Out:
# Empty DataFrame
# Columns: [address, predicted_count, label]
# Index: []

# %% [markdown]
# ## Labelling Predictions

# %%
#import http.cookiejar
#import urllib.parse
#import urllib.request

for adr in ERC1155_scam_preds_top['address']:

    adr_http = 'https://etherscan.io/address/' + adr
    req = Request(adr_http,  
              headers={'User-Agent': 'Mozilla/5.0'})
    page = urlopen(req)
    content = page.read()

    soup = BeautifulSoup(content)

    label = soup.findAll('div', attrs = {'class':'mt-1'})
    if len(label) > 1:
        label = label[1]
        rows = label.findAll('a')
        if len(rows) == 0:
            ERC1155_scam_preds_top.loc[ERC1155_scam_preds_top['address'] == adr, 'label'] = 'None'
        else:
            for row in rows:
                ERC1155_scam_preds_top.loc[ERC1155_scam_preds_top['address'] == adr, 'label'] = row.text
    else:
        ERC1155_scam_preds_top.loc[ERC1155_scam_preds_top['address'] == adr, 'label'] = 'None'

# %%
print(sorted(Counter(ERC1155_scam_preds_top['label']).items()))

#ERC1155_scam_preds_top.to_csv('data/ERC1155_scam_preds_labs.csv')
#ERC1155_scam_preds_top.to_csv('data/ERC1155_scam_preds_labs_2.csv')
# Out:
# [('None', 32)]
